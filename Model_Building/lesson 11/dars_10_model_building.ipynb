# %%
import pandas as pd
df=pd.read_csv("academicStress.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 9 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Timestamp                                                            121 non-null    object
#  1   Your Academic Stage                                                  121 non-null    object
#  2   Peer pressure                                                        121 non-null    int64
#  3   Academic pressure from your home                                     121 non-null    int64
#  4   Study Environment                                                    121 non-null    object
#  5   What coping strategy you use as a student?                           121 non-null    object
#  6   Do you have any bad habits like smoking, drinking on a daily basis?  121 non-null    object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
def encoding(df):
    encoder=LabelEncoder()
    for col in df.columns:
        if df[col].dtype=="object":
            if df[col].nunique()<=5:
                dummies=pd.get_dummies(df[col],prefix=col,dtype=int)
                df=pd.concat([df.drop(columns=col),dummies],axis=1)
            else:
                df[col]=encoder.fit_transform(df[col])
    return df

# %%
df=encoding(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 17 columns):
#  #   Column                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                         --------------  -----
#  0   Timestamp                                                                                      121 non-null    int64
#  1   Peer pressure                                                                                  121 non-null    int64
#  2   Academic pressure from your home                                                               121 non-null    int64
#  3   What would you rate the academic  competition in your student life                             121 non-null    int64
#  4   Rate your academic stress index                                                                121 non-null    int64
# ...

# %% [markdown]
# ## sclaing

# %%
df.head(2)
# Out:
#    Timestamp  Peer pressure  Academic pressure from your home  \
# 0   0.000000           0.75                              1.00
# 1   0.008333           0.50                              0.75
#
#    What would you rate the academic  competition in your student life  \
# 0                                                0.5
# 1                                                0.5
#
#    Rate your academic stress index   Your Academic Stage_high school  \
# 0                               1.0                              0.0
# 1                               0.5                              0.0
#
#    Your Academic Stage_post-graduate  Your Academic Stage_undergraduate  \
# 0                                0.0                                1.0
# 1                                0.0                                1.0
#
#    Study Environment_Noisy  Study Environment_Peaceful  \
# 0                      1.0                         0.0
# ...

# %%
df.columns = df.columns.str.strip()

# %%
from sklearn.preprocessing import MinMaxScaler
# scaler=MinMaxScaler()
# def scaling(df):
#     for col in df.columns:
#         if df[col].dtype != "object":
#             df[col]=scaler.fit_transform(df[[col]])
#     return df
def scaling_qil(df):
    scaler=MinMaxScaler()
    num_col=df.select_dtypes(include=['int64']).columns.drop('Rate your academic stress index')
    df[num_col]=scaler.fit_transform(df[num_col])
    return df

# %%
df=scaling(df)

# %%
x=df.drop("Rate your academic stress index", axis=1)

# %%
y=df["Rate your academic stress index"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2, random_state=42)

# %%
from sklearn.svm import SVC,SVR

# %%
svr=SVR(kernel="rbf",C=1.0)
svr
# Out:
# SVR()

# %%
svr.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred=svr.predict(x_test)

# %%
y_pred
# Out:
# array([0.37164324, 0.6976158 , 0.57721262, 0.73166001, 0.71353091,
#        0.40296143, 0.68139012, 0.51912427, 0.74535128, 0.66352339,
#        0.63138329, 0.86794665, 0.65150312, 0.68194689, 0.74609039,
#        0.57843346, 0.74116964, 0.59474528, 0.4976529 , 0.85327131,
#        0.75565365, 0.58038812, 0.58802582, 0.6960591 , 0.79864662])

# %%
from sklearn.metrics  import r2_score, mean_absolute_error
r2=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)

# %%
print(r2)
print(mae)
# Out:
# 0.10648779602583847
# 0.17963821810128558

# %%
svc=SVC(kernel="linear",C=0.5)
svc
# Out:
# SVC(C=0.5, kernel='linear')

# %%
svc.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 svc.fit(x_train,y_train)
#
# File c:\Users\User\anaconda3\envs\dars_7\lib\site-packages\sklearn\base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# -> 1363     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\User\anaconda3\envs\dars_7\lib\site-packages\sklearn\svm\_base.py:207, in BaseLibSVM.fit(self, X, y, sample_weight)
#     196 else:
#     197     X, y = validate_data(
#     198         self,
#     199         X,
#    (...)
#     204         accept_large_sparse=False,
#     205     )
# --> 207 y = self._validate_targets(y)
# ...

# %% [markdown]
# ## suport vector classifier da xatolik bo'layabdi fit qilib bo'lmayabdi
